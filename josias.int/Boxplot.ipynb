# %%
import matplotlib.pyplot as plt
import seaborn as sns

notas = [5, 7, 8, 6, 9, 5, 10, 4, 6, 8, 9, 7, 6, 10, 3, 2, 8, 7, 9, 10]

plt.figure(figsize=(5, 6))
sns.boxplot(y=notas, color="orange")

plt.ylabel("Notas")
plt.title("Distribuição de Notas dos Alunos")
plt.show()
